# %% [markdown]
# # IIT Data Visualisation

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 2. Load Dataset

# %%
data = pd.read_csv('Marketing.csv')
data
# Out:
#     Campaign ID                    Campaign Name                  Audience  \
# 0    Campaign 1  SHU_6(Educators and Principals)  Educators and Principals
# 1    Campaign 1  SHU_6(Educators and Principals)  Educators and Principals
# 2    Campaign 1  SHU_6(Educators and Principals)  Educators and Principals
# 3    Campaign 1  SHU_6(Educators and Principals)  Educators and Principals
# 4    Campaign 2                  SHU3_(Students)                  Students
# 5    Campaign 2                  SHU3_(Students)                  Students
# 6    Campaign 2                  SHU3_(Students)                  Students
# 7    Campaign 3          SHU_Students(Australia)                  Students
# 8    Campaign 3          SHU_Students(Australia)                  Students
# 9    Campaign 3          SHU_Students(Australia)                  Students
# 10   Campaign 4             SHU_Students(Canada)                  Students
# ...

# %% [markdown]
# ## 3. Description of Data

# %%
data.describe()
# Out:
#               Reach   Impressions  Frequency       Clicks  Unique Clicks  \
# count     33.000000     33.000000  33.000000    33.000000      33.000000
# mean    5723.272727   8783.636364   1.418234   364.393939     288.000000
# std     7671.821261  11327.981290   0.471318   556.340326     432.381125
# min       91.000000    103.000000   1.042614     9.000000       8.000000
# 25%      889.000000   1874.000000   1.131868    49.000000      44.000000
# 50%     2557.000000   3146.000000   1.174759   135.000000     111.000000
# 75%     6145.000000  12372.000000   1.665733   325.000000     246.000000
# max    30110.000000  39161.000000   3.169081  2593.000000    1994.000000
#
#        Unique Link Clicks (ULC)  Click-Through Rate (CTR)  \
# count                 33.000000                 33.000000
# mean                 159.303030                  4.814551
# std                  257.960933                  2.901685
# min                    3.000000                  1.668892
# ...

# %% [markdown]
# ## 4. Data Type of each Variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Campaign ID                             33 non-null     object
#  1   Campaign Name                           33 non-null     object
#  2   Audience                                33 non-null     object
#  3   Age                                     33 non-null     object
#  4   Geography                               33 non-null     object
#  5   Reach                                   33 non-null     int64
#  6   Impressions                             33 non-null     int64
#  7   Frequency                               33 non-null     float64
#  8   Clicks                                  33 non-null     int64
#  9   Unique Clicks                           33 non-null     int64
# ...

# %% [markdown]
# ## 5. Correlation Matrix

# %%
cor = data.corr()
sns.set(rc = {'figure.figsize':(10,10)})

sns.heatmap(cor, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correlation matrix indicates the correlation between each variable. This applies to only continuous variables. Values closer to positive 1 indicate stronger correlation and values closer to negative 1 indicate weaker correlation.

# %% [markdown]
# ## Age groups

# %%
sns.set(rc = {'figure.figsize':(15,10)})

plt.title("Age Demographics of each Campaign")
sns.barplot(x = data['Age'],y = data['Click-Through Rate (CTR)'],data = data, hue = data['Campaign ID'])
plt.show()

# %%
c1 = data[data['Campaign ID'] == 'Campaign 1']
c2 = data[data['Campaign ID'] == 'Campaign 2']
c3 = data[data['Campaign ID'] == 'Campaign 3']
c4 = data[data['Campaign ID'] == 'Campaign 4']
c5 = data[data['Campaign ID'] == 'Campaign 5']
c6 = data[data['Campaign ID'] == 'Campaign 6']
c7 = data[data['Campaign ID'] == 'Campaign 7']
c8 = data[data['Campaign ID'] == 'Campaign 8']
c9 = data[data['Campaign ID'] == 'Campaign 9']
c10 = data[data['Campaign ID'] == 'Campaign 10']
c11 = data[data['Campaign ID'] == 'Campaign 11']

# %%
figure, axis = plt.subplots(3, 4, figsize = (15,15))

axis[0,0].pie(c1['Reach'],labels = c1['Age'],autopct='%.0f%%')
axis[0,0].set_title("Campaign 1")

axis[0,1].pie(c2['Reach'],labels = c2['Age'],autopct='%.0f%%')
axis[0,1].set_title("Campaign 2")

axis[0,2].pie(c3['Reach'],labels = c3['Age'],autopct='%.0f%%')
axis[0,2].set_title("Campaign 3")

axis[0,3].pie(c4['Reach'],labels = c4['Age'],autopct='%.0f%%')
axis[0,3].set_title("Campaign 4")


axis[1,0].pie(c5['Reach'],labels = c5['Age'],autopct='%.0f%%')
axis[1,0].set_title("Campaign 5")

axis[1,1].pie(c6['Reach'],labels = c6['Age'],autopct='%.0f%%')
axis[1,1].set_title("Campaign 6")

axis[1,2].pie(c7['Reach'],labels = c7['Age'],autopct='%.0f%%')
axis[1,2].set_title("Campaign 7")

axis[1,3].pie(c8['Reach'],labels = c8['Age'],autopct='%.0f%%')
axis[1,3].set_title("Campaign 8")


axis[2,0].pie(c9['Reach'],labels = c9['Age'],autopct='%.0f%%')
axis[2,0].set_title("Campaign 9")

axis[2,1].pie(c10['Reach'],labels = c10['Age'],autopct='%.0f%%')
axis[2,1].set_title("Campaign 10")

axis[3,2].pie(c11['Reach'],labels = c11['Age'],autopct='%.0f%%')
axis[3,2].set_title("Campaign 11")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-7177a4a584c9> in <module>
#      33 axis[2,1].set_title("Campaign 10")
#      34
# ---> 35 axis[3,2].pie(c11['Reach'],labels = c11['Age'],autopct='%.0f%%')
#      36 axis[3,2].set_title("Campaign 11")
#      37
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# From the above Pie charts, it is clear that majority of the campaigns have an audience in the 18-24 age group.

# %% [markdown]
# ## Number of Campaigns

# %%
sns.set(rc = {'figure.figsize':(5,5)})

ax = sns.countplot(x = data['Campaign ID'], data = data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Count of Campaigns")
plt.show()

# %% [markdown]
# ## Grouping by Campaign

# %%
campaign_data = data.groupby(["Campaign ID"])['Reach','Impressions','Clicks','Unique Clicks','Unique Link Clicks (ULC)','Unique Click-Through Rate (Unique CTR)','Amount Spent in INR'].sum().reset_index()
campaign_data
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#     Campaign ID  Reach  Impressions  Clicks  Unique Clicks  \
# 0    Campaign 1  23904        47139    1218            967
# 1   Campaign 10   3636         4091     121            105
# 2   Campaign 11   2555         2900     178            156
# 3    Campaign 2  46494        67313    3743           2833
# 4    Campaign 3   3187         3572     119            109
# 5    Campaign 4   3307         4267     171            146
# 6    Campaign 5  15024        20483     648            552
# 7    Campaign 6  31831        37246    1400           1238
# 8    Campaign 7  29668        65215    1420           1146
# 9    Campaign 8  21929        28974    2765           2058
# 10   Campaign 9   7333         8660     242            194
#
# ...

# %%
campaign_data['Frequency'] = campaign_data['Impressions']/campaign_data['Reach']
campaign_data['Click-Through Rate (CTR)'] = (campaign_data['Clicks']/campaign_data['Impressions'])*100
campaign_data['Cost Per Click (CPC)'] = campaign_data['Amount Spent in INR']/campaign_data['Clicks']
campaign_data['Cost Per Result (CPR)'] = campaign_data['Amount Spent in INR']/campaign_data['Unique Link Clicks (ULC)']
campaign_data
# Out:
#     Campaign ID  Reach  Impressions  Clicks  Unique Clicks  \
# 0    Campaign 1  23904        47139    1218            967
# 1   Campaign 10   3636         4091     121            105
# 2   Campaign 11   2555         2900     178            156
# 3    Campaign 2  46494        67313    3743           2833
# 4    Campaign 3   3187         3572     119            109
# 5    Campaign 4   3307         4267     171            146
# 6    Campaign 5  15024        20483     648            552
# 7    Campaign 6  31831        37246    1400           1238
# 8    Campaign 7  29668        65215    1420           1146
# 9    Campaign 8  21929        28974    2765           2058
# 10   Campaign 9   7333         8660     242            194
#
#     Unique Link Clicks (ULC)  Unique Click-Through Rate (Unique CTR)  \
# 0                        420                               17.414206
# 1                         57                               10.089332
# ...

# %%
sns.set(rc = {'figure.figsize':(5,5)})

sns.scatterplot(x = campaign_data['Frequency'], y = data['Click-Through Rate (CTR)'], data = campaign_data)
plt.show()

# %% [markdown]
# ## Campaign vs Reach

# %%
sns.set(rc = {'figure.figsize':(7,7)})

ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Reach'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Reach")
plt.axhline(y=np.nanmean(campaign_data['Reach']),color = 'red')
offset = 10
#plt.text(0, campaign_data['Reach'].mean(), campaign_data['Reach'].mean()+offset)
st = str(round(np.nanmean(campaign_data['Reach']),2))
st = st + " - Mean"
ax.text(1,np.nanmean(campaign_data['Reach']) , st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# In the above plot, the red line indicates the average reach of all the campaigns. Campaign 3,4,5,9,10 and 11 are below the average reach.

# %% [markdown]
# ## Campaign vs Impressions

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Impressions'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Impressions")
plt.axhline(y=np.nanmean(campaign_data['Impressions']),color = 'red')
st = str(round(np.nanmean(campaign_data['Impressions']),2))
st = st + " - Mean"
ax.text(1,np.nanmean(campaign_data['Impressions']) + 2 , st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# In the above plot, the red line indicates the average impression of all the campaigns. Campaign 3,4,5,9,10 and 11 are below the average impression.

# %% [markdown]
# ## Campaign vs Frequency

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = round(campaign_data['Frequency'],2), data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Frequency")
plt.axhline(y=(campaign_data['Impressions'].sum()/campaign_data['Reach'].sum()),color = 'red')
st = str(round(campaign_data['Impressions'].sum()/campaign_data['Reach'].sum(),2))
st = st + " - Mean"
ax.text(1, round(campaign_data['Impressions'].sum()/campaign_data['Reach'].sum())-0.47, st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# In the above plot, the red line indicates the average frequency of all the campaigns. Campaigns 1 and 7 have a higher frequency. This indicates that the ad appears on the user screen more often than the other campaigns.

# %% [markdown]
# ## Campaign vs Clicks

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Clicks'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Clicks")
plt.axhline(y=np.nanmean(campaign_data['Clicks']),color = 'red')
st = str(round(np.nanmean(campaign_data['Clicks']),2))
st = st + " - Mean"
ax.text(1, round(np.nanmean(campaign_data['Clicks']),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# The red line indicates the average number of clicks. Campaign 2 and 8 have far more number of clicks when compared to the average.

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Unique Clicks'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Unique Clicks")
plt.axhline(y=np.nanmean(campaign_data['Unique Clicks']),color = 'red')
st = str(round(np.nanmean(campaign_data['Unique Clicks']),2))
st = st + " - Mean"
ax.text(1, round(np.nanmean(campaign_data['Unique Clicks']),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Unique Link Clicks (ULC)'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Unique Links Clicks (ULC)")
plt.axhline(y=np.nanmean(campaign_data['Unique Link Clicks (ULC)']),color = 'red')
st = str(round(np.nanmean(campaign_data['Unique Link Clicks (ULC)']),2))
st = st + " - Mean"
ax.text(1, round(np.nanmean(campaign_data['Unique Link Clicks (ULC)']),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = campaign_data['Unique Click-Through Rate (Unique CTR)'], data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs Unique CTR")
plt.axhline(y=np.nanmean(campaign_data['Unique Click-Through Rate (Unique CTR)']),color = 'red')
st = str(round(np.nanmean(campaign_data['Unique Click-Through Rate (Unique CTR)']),2))
st = st + " - Mean"
ax.text(1, round(np.nanmean(campaign_data['Unique Click-Through Rate (Unique CTR)']),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# ## Campaign vs CTR

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = round(campaign_data['Click-Through Rate (CTR)'],2), data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs CTR")
plt.axhline(y=(campaign_data['Clicks'].sum()/campaign_data['Impressions'].sum())*100,color = 'red')
st = str(round((campaign_data['Clicks'].sum()/campaign_data['Impressions'].sum()*100),2))
st = st + " - Mean"
ax.text(1, round(campaign_data['Clicks'].sum()/campaign_data['Impressions'].sum()*100,2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# The red line indicates the average click through rate. Campaign 2,8 and 11 have a CTR higher than the average.

# %% [markdown]
# ## Campaign vs CPC

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = round(campaign_data['Cost Per Click (CPC)'],2), data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs CPC")
plt.axhline(y=(campaign_data['Amount Spent in INR'].sum()/campaign_data['Clicks'].sum()),color = 'red')
st = str(round((campaign_data['Amount Spent in INR'].sum()/campaign_data['Clicks'].sum()),2))
st = st + " - Mean"
ax.text(1, round((campaign_data['Amount Spent in INR'].sum()/campaign_data['Clicks'].sum()),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# The red line indicates the average CPC. Campaign 3 and 10 have a significantly higher CPC than the average.

# %% [markdown]
# ## Campaign vs CPR

# %%
ax = sns.barplot(x = campaign_data['Campaign ID'],y = round(campaign_data['Cost Per Result (CPR)'],2), data = campaign_data)
ax.bar_label(ax.containers[0])
plt.xticks(rotation = 90)
plt.title("Campaign vs CPR")
plt.axhline(y=(campaign_data['Amount Spent in INR'].sum()/campaign_data['Unique Link Clicks (ULC)'].sum()),color = 'red')
st = str(round((campaign_data['Amount Spent in INR'].sum()/campaign_data['Unique Link Clicks (ULC)'].sum()),2))
st = st + " - Mean"
ax.text(1, round((campaign_data['Amount Spent in INR'].sum()/campaign_data['Unique Link Clicks (ULC)'].sum()),2), st, va='center', ha="left",transform=ax.get_yaxis_transform())
plt.show()

# %% [markdown]
# The red line indicates the average CPR. Campaign 3 and 10 have a higher CPR than the average.

# %% [markdown]
# Campaign 3 and 10 have very low reach and impressions. They also have a high CPC and CPR when compared to rest of the campaigns. Therefore, we suggest to discontinue campaign 3 and 10.
